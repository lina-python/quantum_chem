# %% [markdown]
# ## Атомные орбитали(базисные функции) 1s_a и 1s_b:

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.plot(x, np.exp(-abs(x+0.5))*(math.pi)**(-1/2),color="red", label="$x_a$ = -0.5")
plt.plot(x, np.exp(-abs(x-0.5))*(math.pi)**(-1/2),color="blue", label="$x_b$ = 0.5")
plt.axvline(-0.5, color='black', alpha = 0.3)
plt.axvline(0.5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 1")

plt.subplot(2, 2, 2)
plt.plot(x, np.exp(-abs(x+1))*(math.pi)**(-1/2),color="red", label="$x_a$ = -1")
plt.plot(x, np.exp(-abs(x-1))*(math.pi)**(-1/2),color="blue", label="$x_b$ = 1")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 2")

plt.subplot(2, 2, 3)
plt.plot(x, np.exp(-abs(x+2.5))*(math.pi)**(-1/2),color="red", label="$x_a$ = -2.5")
plt.plot(x, np.exp(-abs(x-2.5))*(math.pi)**(-1/2),color="blue", label="$x_b$ = 2.5")
plt.axvline(-2.5, color='black', alpha = 0.3)
plt.axvline(2.5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 5")


plt.subplot(2, 2, 4)
plt.plot(x, np.exp(-abs(x+5))*(math.pi)**(-1/2),color="red", label="$x_a$ = -5")
plt.plot(x, np.exp(-abs(x-5))*(math.pi)**(-1/2),color="blue", label="$x_b$ = 5")
plt.axvline(-5, color='black', alpha = 0.3)
plt.axvline(5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 10")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.plot(x, ((np.exp(-abs(x+0.5))*(math.pi)**(-0.5) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2+2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5), color="blue", label="$x_a$ = -0.5", alpha=0.2)
plt.plot(x, ((np.exp(-abs(x+0.5))*(math.pi)**(-0.5) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2+2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5), color="red", label="$x_b$ = 0.5")
plt.axvline(-0.5, color='black', alpha = 0.3)
plt.axvline(0.5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 1")

plt.subplot(2, 2, 2)
plt.plot(x, ((np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2+2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5), color="blue", label="$x_a$ = -1", alpha=0.2)
plt.plot(x, ((np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2+2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5), color="red", label="$x_b$ = 1")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 2")

plt.subplot(2, 2, 3)
plt.plot(x, ((np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2+2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5), color="blue", label="$x_a$ = -2.5", alpha=0.2)
plt.plot(x, ((np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2+2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5), color="red", label="$x_b$ = 2.5")
plt.axvline(-2.5, color='black', alpha = 0.3)
plt.axvline(2.5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 5")


plt.subplot(2, 2, 4)
plt.plot(x, ((np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2+2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5), color="blue", label="$x_a$ = -5", alpha=0.2)
plt.plot(x, ((np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2+2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5), color="red", label="$x_b$ = 5")
plt.axvline(-5, color='black', alpha = 0.3)
plt.axvline(5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 10")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

xmin = -10.0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.plot(x, ((-np.exp(-abs(x+0.5))*(math.pi)**(-0.5) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2-2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5), color="blue", label="$x_a$ = -0.5", alpha=0.2)
plt.plot(x, ((-np.exp(-abs(x+0.5))*(math.pi)**(-0.5) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2-2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5), color="red", label="$x_b$ = 0.5")
plt.axvline(-0.5, color='black', alpha = 0.3)
plt.axvline(0.5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 1")

plt.subplot(2, 2, 2)
plt.plot(x, ((-np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2-2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5), color="blue", label="$x_a$ = -1", alpha=0.2)
plt.plot(x, ((-np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2-2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5), color="red", label="$x_a$ = 1")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 2")

plt.subplot(2, 2, 3)
plt.plot(x, ((-np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2-2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5), color="blue", label="$x_a$ = -2.5", alpha=0.2)
plt.plot(x, ((-np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2-2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5), color="red", label="$x_b$ = 2.5")
plt.axvline(-2.5, color='black', alpha = 0.3)
plt.axvline(2.5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 5")


plt.subplot(2, 2, 4)
plt.plot(x, ((-np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2-2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5), color="blue", label="$x_a$ = -5", alpha=0.2)
plt.plot(x, ((-np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2-2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5), color="red", label="$x_b$ = 5")
plt.axvline(-5, color='black', alpha = 0.3)
plt.axvline(5, color='black', alpha = 0.3)
plt.legend(loc="upper left")
plt.title("R = 10")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(7, 7))

plt.plot(x, ((np.exp(-abs(x+0.5))*(math.pi)**(-0.5) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2+2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5), color="red")

plt.plot(x, ((np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2+2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5), color="blue")

plt.plot(x, ((np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2+2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5), color="green")

plt.plot(x, ((np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2+2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5), color="purple")
plt.title("МО для разных R для разрыхляющей орбитали", fontsize=20, fontname='Times New Roman')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(7, 7))

plt.plot(x, ((-np.exp(-abs(x+0.5))*(math.pi)**(-0.5) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2-2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5), color="red")

plt.plot(x, ((-np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2-2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5), color="blue")

plt.plot(x, ((-np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2-2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5), color="green")

plt.plot(x, ((-np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2-2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5), color="purple")
plt.title("МО для разных R для разрыхляющей орбитали", fontsize=20, fontname='Times New Roman')
plt.show()

# %% [markdown]
# ## Электронная плотность для разрыхляющих орбиталей:

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.plot(x, (((-np.exp(-abs(x+0.5))*(math.pi)**(-1/2) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2-2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5))**2, color="red")
plt.axvline(-0.5, color='black', alpha = 0.3)
plt.axvline(0.5, color='black', alpha = 0.3)
plt.title("R = 1")

plt.subplot(2, 2, 2)
plt.plot(x, (((-np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2-2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5))**2, color="red")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.title("R = 2")

plt.subplot(2, 2, 3)
plt.plot(x, (((-np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2-2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5))**2, color="red")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.title("R = 5")

plt.subplot(2, 2, 4)
plt.plot(x, (((-np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2-2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5))**2, color="red")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.title("R = 10")



plt.show()

# %% [markdown]
# ## Электронная плотность для связывающих орбиталей:

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))

plt.subplot(2, 2, 1)
plt.plot(x, (((np.exp(-abs(x+0.5))*(math.pi)**(-1/2) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2+2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5))**2, color="red")
plt.axvline(-0.5, color='black', alpha = 0.3)
plt.axvline(0.5, color='black', alpha = 0.3)
plt.title("R = 1")

plt.subplot(2, 2, 2)
plt.plot(x, (((np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2+2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5))**2, color="red")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.title("R = 2")

plt.subplot(2, 2, 3)
plt.plot(x, (((np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2+2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5))**2, color="red")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.title("R = 5")

plt.subplot(2, 2, 4)
plt.plot(x, (((np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2+2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5))**2, color="red")
plt.axvline(-1, color='black', alpha = 0.3)
plt.axvline(1, color='black', alpha = 0.3)
plt.title("R = 10")



plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))

plt.plot(x, (((-np.exp(-abs(x+0.5))*(math.pi)**(-1/2) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2-2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5))**2, color="red")

plt.plot(x, (((-np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2-2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5))**2, color="blue")

plt.plot(x, (((-np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2-2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5))**2, color="green")

plt.plot(x, (((-np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2-2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5))**2, color="purple")

plt.title("Электронная плотность для разрыхляющих орбиталей на одном графике", fontsize=20, fontname='Times New Roman')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200


x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))

plt.plot(x, (((np.exp(-abs(x+0.5))*(math.pi)**(-1/2) + np.exp(-abs(x-0.5))*(math.pi)**(-1/2))/(2+2*np.exp(-0.5)*(1 + 0.5 + 0.5**2/3))**0.5))**2, color="red")

plt.plot(x, (((np.exp(-abs(x+1))*(math.pi)**(-1/2) + np.exp(-abs(x-1))*(math.pi)**(-1/2))/(2+2*np.exp(-1)*(1 + 1 + 1**2/3))**0.5))**2, color="blue")

plt.plot(x, (((np.exp(-abs(x+2.5))*(math.pi)**(-1/2) + np.exp(-abs(x-2.5))*(math.pi)**(-1/2))/(2+2*np.exp(-2.5)*(1 + 2.5 + 2.5**2/3))**0.5))**2, color="green")

plt.plot(x, (((np.exp(-abs(x+5))*(math.pi)**(-1/2) + np.exp(-abs(x-5))*(math.pi)**(-1/2))/(2+2*np.exp(-5)*(1 + 5 + 5**2/3))**0.5))**2, color="purple")

plt.title("Электронная плотность для связывающих орбиталей на одном графике", fontsize=20, fontname='Times New Roman')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xmin = -10.0
xmax = 10.0
count = 200

# Промолекулярная ЭП для разных R на одном графике

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))

plt.plot(x, 0.5*(np.exp(-abs(x+0.5))*(math.pi)**(-1/2))**2 + 0.5*(np.exp(-abs(x-0.5))*(math.pi)**(-1/2))**2 ,color="red")


plt.plot(x, 0.5*(np.exp(-abs(x+1))*(math.pi)**(-1/2))**2 + 0.5*(np.exp(-abs(x-1))*(math.pi)**(-1/2))**2 ,color="blue")


plt.plot(x, 0.5*(np.exp(-abs(x+2.5))*(math.pi)**(-1/2))**2 + 0.5*(np.exp(-abs(x-2.5))*(math.pi)**(-1/2))**2 ,color="green")


plt.plot(x, 0.5*(np.exp(-abs(x+5))*(math.pi)**(-1/2))**2 + 0.5*(np.exp(-abs(x-5))*(math.pi)**(-1/2))**2 ,color="purple")
plt.title("Промолекулярная ЭП для разных R на одном графике", fontsize=20, fontname='Times New Roman')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


r = np.linspace(0, 6, 100)
plt.plot(r, np.exp(-r)*(1 + r + r**2/3),color="red")
plt.title('Интеграл перекрывания S(r)', fontsize=20, fontname='Times New Roman')

plt.xlabel("$r$")
plt.ylabel(r"$S$")
plt.show()

# %%
xmin = 0
xmax = 10.0
count = 200

x = np.linspace(xmin, xmax, count)

plt.figure(figsize=(8, 8))
plt.plot(x, (2 + 2*np.exp(-x)*(1+x + x**2/3))**0.5,color="red")
plt.plot(x, (2 - 2*np.exp(-x)*(1+x + x**2/3))**0.5,color="green")
plt.title('Нормировочныe коэффициенты $N_g$ и $N_u$', fontsize=20, fontname='Times New Roman')
plt.xlabel("$r$")
plt.ylabel(r"$S$")
plt.show()

# %% [markdown]
# $$E_{H} = -\frac{1}{2}$$
#
# $$\epsilon_{ab}(R = 1) = -0.735759$$
# $$\epsilon_{ab}(R = 2) = -0.406006$$
# $$\epsilon_{ab}(R = 5) = -0.040428$$
# $$\epsilon_{ab}(R = 10) = -0.000499$$

# %% [markdown]
# $$\epsilon_{aa}(R = 1) = -0.729329$$
# $$\epsilon_{aa}(R = 2) = -0.472527$$
# $$\epsilon_{aa}(R = 5) = -0.199946$$
# $$\epsilon_{aa}(R = 10) = -0.099999$$

# %% [markdown]
# $$S(R = 1) = 0.858385$$
# $$S(R = 2) = 0.586453$$
# $$S(R = 5) = 0.0965772$$
# $$S(R = 10) = 0.002013$$

# %% [markdown]
# $$H_{ab}(R = 1) = -0.3065663$$
# $$H_{ab}(R = 2) = -0.406006$$
# $$H_{ab}(R = 5) = -0.06940116$$
# $$H_{ab}(R = 10) = -0.0013042$$

# %% [markdown]
# $$H_{aa}(R = 1) = -0.229329$$
# $$H_{aa}(R = 2) = -0.472527$$
# $$H_{aa}(R = 5) = -0.499946$$
# $$H_{aa}(R = 10) = -0.499999$$

# %% [markdown]
# $$E_u(R = 1) = 0.545019$$
# $$E_u(R = 2) = -0.160855$$
# $$E_u(R = 5) = -0.476571$$
# $$E_u(R = 10) = -0.499700$$

# %% [markdown]
# $$E_g(R = 1) = -0.288366$$
# $$E_g(R = 2) = -0.553772$$
# $$E_g(R = 5) = -0.519203$$
# $$E_g(R = 10) = -0.500296$$

# %%
xmin = 0.1
xmax = 3
count = 200

x = np.linspace(xmin, xmax, count)
plt.figure(figsize=(8, 8))

#H_aa = -0.5 - (1-np.exp(-2*x)*(1+x))/x + 1/x
#H_ab = -0.5*(np.exp(-x)*(1+x+x**2/3)) - np.exp(-x)*(1+x) + np.exp(-x)*(1+x+x**2/3)/x

#S = np.exp(-x)*(1+x+x**2/3)
#eps_ab = -np.epx(-x)*(1+x)
#eps_aa = -1/x*(1 -np.exp(-2*x)*(1+x))


plt.plot(x, -0.5 + 1/x + ((-1/x*(1 -np.exp(-2*x)*(1+x))) + (-np.exp(-x)*(1+x)))/(1 + np.exp(-x)*(1+x+x**2/3)), color="red")
plt.plot(x, -0.5 + 1/x + ((-1/x*(1 -np.exp(-2*x)*(1+x))) - (-np.exp(-x)*(1+x)))/(1 - np.exp(-x)*(1+x+x**2/3)), color="blue")

plt.title('Энергии связывающего и разрыхляющего состояний $E_g$ и $E_u$', fontsize=20, fontname='Times New Roman')
plt.xlabel("$r$")
plt.ylabel(r"$S$")
plt.show()
